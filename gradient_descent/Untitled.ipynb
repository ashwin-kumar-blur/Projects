# %% [markdown]
# # Objective:- Build Sustainable Analytics that will give the Organisation an Edge over its Competitors.
#
# Current work:- Working as a Senior Machine Learning Consultant with BNP Paribas since June 2018.
#
# Current Project :- Reggie (Regulatory Generic Intelligence Engine)
# The Project made it to the 2018 Innovation Awards finals and won a sponsorship from the Exco to be implemented for regulatory Complaince.
#
# Business Problem:- Every day thousands of trades that are booked get rejected by the Regulators due to data quality and incomplete information, currently the bank uses the services of third party organsisations that act as a layer of filter to check for any such data issues. REGGIE is built to replace the third party services and save Money for the organisation.The Solution works autonomously and also along side a domain expert. The delivery is by a Desktop stand alone application and API. Reggie makes use of Gentic algorithm accompanied by a bayesian search Agent for optimal solution.
#
# Technology stack:-
# 	1) Oracle DB is used to ingest and store data such as Training data, dashboard data, reconciled 		    data etc.
# 	2) Python for Machine learning and other modules like data-type inferences.
# 	3) Power-BI for dashboards.
# 	4) .net for Configuration UI.
#
#
#
# Other information:- Reggie was also pitched to other departments such as Performance Forecasting and HR with positive feedback.
#
# My Strengths:- Relentless in pursuit of improvement, love to read, Calm under pressure.
#
# My Weaknesses:- Articulating to the stake holders.
#
# How I am handling my weaknesses:- I take Data science sessions internally to a group of 10 Individuals, I am learning how to simplify things so that it can be assimilated with less effort.
#
# last job :- Free a Billion (June 2017 to Jaunuary 2018) as an Intern Data Analyst and later as an  	employee after 2 months of Internship. Learned data extraction, processing and writing cronjobs 	for extraction on ubuntu. Not much on data analytics but got to learn many aspects of coding 	and IT infrastructure.
#
# Other past work experiences:- I  worked in telecom Domain with all the leading telcos as a Business Development Executive / Manager for 5 years. During my stint in the telecom domain I developed inclination towards Data science therefore I choose to quit my job as a Circle Manager with Mahindra Comviva to obtain Education from Aegis School of Data Science in 2016 as a full-time Student.
#
# My learning path for this year :- Natural Language processing(would soon work on building a conversational bot using RASA stack), Corporate Finance(started) and Calculus

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
import bokeh
from bokeh.io import output_notebook
output_notebook()
from math import pi
import pandas as pd
from bokeh.io import output_file, show
from bokeh.palettes import Category20c
from bokeh.plotting import figure
from bokeh.transform import cumsum

output_file("pie.html")

x = {
    'Python': 40,
    'Machine Learning & Statistics': 25,
    'SQL': 14,
    'MS Excel': 12,
    'Git': 4,
    'Jira': 4,
    }

data = pd.Series(x).reset_index(name='value').rename(columns={'index':'Skills'})
data['angle'] = data['value']/data['value'].sum() * 2*pi
data['color'] = Category20c[len(x)]

p = figure(plot_height=350, title="Skillset and usage in a day's work", toolbar_location=None,
           tools="hover", tooltips="@Skills : @value", x_range=(-0.5, 1.0))

p.wedge(x=0, y=1, radius=0.4,
        start_angle=cumsum('angle', include_zero=True), end_angle=cumsum('angle'),
        line_color="white", fill_color='color', legend_field='Skills', source=data)

p.axis.axis_label=None
p.axis.visible=False
p.grid.grid_line_color = None
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="51f39362-5a5d-456a-a300-3f6f8ae0e9fa" data-root-id="1002"></div>
